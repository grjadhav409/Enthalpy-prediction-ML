# %% [markdown]
# <a href="https://colab.research.google.com/github/grjadhav409/Enthalpy-prediction-ML/blob/main/5_Modelbuilding_FlamML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dfx= pd.read_excel('/content/drive/MyDrive/Colab Notebooks/data2/Enthalpy of formation enthalpy of formation/hydrocarbans/df3_X.xlsx')
dfy= pd.read_excel('/content/drive/MyDrive/Colab Notebooks/data2/Enthalpy of formation enthalpy of formation/hydrocarbans/df3_Y.xlsx')

# %%
dfx
# Out:
#      PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0             1           1  ...             0             0
# 1             1           1  ...             0             0
# 2             1           1  ...             0             0
# 3             1           1  ...             0             0
# 4             1           1  ...             0             0
# ..          ...         ...  ...           ...           ...
# 405           1           0  ...             0             0
# 406           0           0  ...             0             0
# 407           1           0  ...             0             0
# 408           1           0  ...             0             0
# 409           1           1  ...             0             0
#
# [410 rows x 881 columns]

# %%
dfy
# Out:
#             hfg
# 0   -249.699997
# 1   -228.300003
# 2   -226.199997
# 3   -208.399994
# 4   -195.000000
# ..          ...
# 405  118.000000
# 406  126.000000
# 407  147.300003
# 408  176.699997
# 409  209.660004
#
# [410 rows x 1 columns]

# %%
dataframe = pd.concat([dfx, dfy],axis=1)
dataframe
# Out:
#      PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880         hfg
# 0             1           1           1  ...             0             0 -249.699997
# 1             1           1           1  ...             0             0 -228.300003
# 2             1           1           1  ...             0             0 -226.199997
# 3             1           1           1  ...             0             0 -208.399994
# 4             1           1           1  ...             0             0 -195.000000
# ..          ...         ...         ...  ...           ...           ...         ...
# 405           1           0           0  ...             0             0  118.000000
# 406           0           0           0  ...             0             0  126.000000
# 407           1           0           0  ...             0             0  147.300003
# 408           1           0           0  ...             0             0  176.699997
# ...

# %%
df = dataframe[dataframe['hfg'].notna()]
df
# Out:
#      PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880         hfg
# 0             1           1           1  ...             0             0 -249.699997
# 1             1           1           1  ...             0             0 -228.300003
# 2             1           1           1  ...             0             0 -226.199997
# 3             1           1           1  ...             0             0 -208.399994
# 4             1           1           1  ...             0             0 -195.000000
# ..          ...         ...         ...  ...           ...           ...         ...
# 405           1           0           0  ...             0             0  118.000000
# 406           0           0           0  ...             0             0  126.000000
# 407           1           0           0  ...             0             0  147.300003
# 408           1           0           0  ...             0             0  176.699997
# ...

# %%
df
# Out:
#      PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880         hfg
# 0             1           1           1  ...             0             0 -249.699997
# 1             1           1           1  ...             0             0 -228.300003
# 2             1           1           1  ...             0             0 -226.199997
# 3             1           1           1  ...             0             0 -208.399994
# 4             1           1           1  ...             0             0 -195.000000
# ..          ...         ...         ...  ...           ...           ...         ...
# 405           1           0           0  ...             0             0  118.000000
# 406           0           0           0  ...             0             0  126.000000
# 407           1           0           0  ...             0             0  147.300003
# 408           1           0           0  ...             0             0  176.699997
# ...

# %%
X = df.drop(['hfg'], axis=1)

# %%
Y = df.hfg

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor
import seaborn as sns
from sklearn.metrics import mean_squared_error, r2_score
model = linear_model.LinearRegression()
model.fit(X_train, Y_train)
Y_pred = model.predict(X_test)
print('Coefficients:', model.coef_)
print('Intercept:', model.intercept_)
print('Mean squared error (MSE): %.2f'
      % mean_squared_error(Y_test, Y_pred))
print('Coefficient of determination (R^2): %.2f'
      % r2_score(Y_test, Y_pred))
# Out:
# Coefficients: [ 2.25995688e+01 -1.78682672e+01 -8.65913806e+01 -1.52498757e+13
#   7.19528846e+14  1.67531024e+15 -9.91321914e+14  1.94361175e+15
#  -2.76508733e+15  4.41945302e+01  3.02758938e+01  1.72562043e+02
#   3.30916935e+15 -8.63379326e+14  5.99818449e+14  1.95573447e+02
#   1.24073265e+15 -6.75387812e+14 -9.29348620e+12 -1.44209381e+03
#   1.16199976e+15  8.63455346e+14 -2.78237251e+14 -7.98693232e+12
#  -3.49815402e+14 -6.74073926e+14  2.16465247e+15 -5.66771791e+15
#  -5.02452614e+14  1.10277191e+15  1.25650509e+15 -6.05719120e+14
#   3.25007714e+14  3.20213928e+12  1.35839844e+01  1.20424725e+14
#   2.38637791e+14  4.06269219e+14 -4.94375000e+01  3.20852026e+14
#  -1.22836811e+14  1.16602524e+14 -5.07784203e+14  1.06745488e+14
#   2.38557129e+01 -6.05414384e+13 -2.81856576e+12  9.04951172e+01
#  -1.96495839e+14  4.85842620e+13 -2.88304341e+13 -1.58963360e+14
#   1.94661609e+13  2.01931242e+14 -6.84526071e+13  2.00583083e+14
# ...

# %%
"""from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)
"""
# Out:
# 'from sklearn.feature_selection import VarianceThreshold\nselection = VarianceThreshold(threshold=(.8 * (1 - .8)))    \nX = selection.fit_transform(X)\n'

# %%
X.shape
# Out:
# (409, 881)

# %%
model = RandomForestRegressor(n_estimators=100)
model.fit(X_train, Y_train)
r2 = model.score(X_test, Y_test)
r2
# Out:
# 0.34598868564154117

# %%
# !pip install flaml
from flaml import AutoML
# Out:
# ...
#      |████████████████████████████████| 143 kB 20.1 MB/s
# ...
#      |████████████████████████████████| 2.0 MB 39.8 MB/s
# ...
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 2.2.3
#     Uninstalling lightgbm-2.2.3:
#       Successfully uninstalled lightgbm-2.2.3
# ...

# %%
#from sklearn.datasets import load_boston

automl = AutoML()

automl_settings = {
    "time_budget": 10,  # in seconds
    "metric": 'r2',
    "task": 'regression'
}
#X_train, y_train = load_boston(return_X_y=True)
# Train with labeled input data
automl.fit(X_train, Y_train,
           **automl_settings)
# Predict
print(automl.predict(X_train).shape)
# Export the best model
print(automl.model)
# Out:
# [flaml.automl: 02-15 08:18:19] {2055} INFO - task = regression
# [flaml.automl: 02-15 08:18:19] {2057} INFO - Data split method: uniform
# [flaml.automl: 02-15 08:18:19] {2061} INFO - Evaluation method: holdout
# [flaml.automl: 02-15 08:18:19] {2142} INFO - Minimizing error metric: 1-r2
# [flaml.automl: 02-15 08:18:19] {2200} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth']
# [flaml.automl: 02-15 08:18:19] {2453} INFO - iteration 0, current learner lgbm
# [flaml.automl: 02-15 08:18:20] {2569} INFO - Estimated sufficient time budget=3977s. Estimated necessary time budget=28s.
# [flaml.automl: 02-15 08:18:20] {2621} INFO -  at 1.4s,	estimator lgbm's best error=0.8608,	best estimator lgbm's best error=0.8608
# [flaml.automl: 02-15 08:18:20] {2453} INFO - iteration 1, current learner lgbm
# [flaml.automl: 02-15 08:18:20] {2621} INFO -  at 1.4s,	estimator lgbm's best error=0.8608,	best estimator lgbm's best error=0.8608
# ...

# %%
print('Best ML leaner:', automl.best_estimator)
print('Best hyperparmeter config:', automl.best_config)
print('Best accuracy on validation data: {0:.4g}'.format(1-automl.best_loss))
print('Training duration of best run: {0:.4g} s'.format(automl.best_config_train_time))
# Out:
# Best ML leaner: lgbm
# Best hyperparmeter config: {'n_estimators': 13, 'num_leaves': 16, 'min_child_samples': 12, 'learning_rate': 1.0, 'log_max_bin': 10, 'colsample_bytree': 0.6327073691111441, 'reg_alpha': 0.0022643161200084742, 'reg_lambda': 0.9218257482254287}
# Best accuracy on validation data: 0.6363
# Training duration of best run: 1.051 s
